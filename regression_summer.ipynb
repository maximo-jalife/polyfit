# %%
#Read data from excel files
#File location might vary


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

file = open('/Users/mjalife/Desktop/data_contour/summer0.csv')
summer0 = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/summer20s.csv')
summer20s = pd.read_csv(file)

file = open('/Users/mjalife/Desktop/data_contour/summer20n.csv')
summer20n = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/summer40s.csv')
summer40s = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/summer40n.csv')
summer40n = pd.read_csv(file)

file = open('/Users/mjalife/Desktop/data_contour/summer60s.csv')
summer60s = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/summer60n.csv')
summer60n = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/summer80s.csv')
summer80s = pd.read_csv(file)

file = open('/Users/mjalife/Desktop/data_contour/summer80n.csv')
summer80n = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/summer90s.csv')
summer90s = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/summer90n.csv')
summer90n = pd.read_csv(file)

summer0
# Out:
#      height, km     O, cm-3      N2, cm-3      O2, cm-3  Mass_density, g/cm-3  \
# 0          40.0         0.0  6.759000e+16  1.813000e+16          4.158000e-06
# 1          40.5         0.0  6.297000e+16  1.689000e+16          3.874000e-06
# 2          41.0         0.0  5.870000e+16  1.575000e+16          3.611000e-06
# 3          41.5         0.0  5.474000e+16  1.468000e+16          3.368000e-06
# 4          42.0         0.0  5.106000e+16  1.370000e+16          3.142000e-06
# ..          ...         ...           ...           ...                   ...
# 916       498.0  22390000.0  3.929000e+05  6.071000e+03          6.338000e-16
# 917       498.5  22210000.0  3.873000e+05  5.973000e+03          6.286000e-16
# 918       499.0  22030000.0  3.818000e+05  5.876000e+03          6.234000e-16
# 919       499.5  21850000.0  3.764000e+05  5.780000e+03          6.183000e-16
# 920       500.0  21670000.0  3.710000e+05  5.687000e+03          6.133000e-16
#
#         He, cm-3       Ar, cm-3  H, cm-3   N, cm-3
# 0    4.535000e+11  8.084000e+14      0.0       0.0
# 1    4.226000e+11  7.533000e+14      0.0       0.0
# 2    3.939000e+11  7.021000e+14      0.0       0.0
# 3    3.673000e+11  6.547000e+14      0.0       0.0
# 4    3.427000e+11  6.108000e+14      0.0       0.0
# ..            ...           ...      ...       ...
# 916  1.767000e+06  6.700000e+00  73970.0  371200.0
# 917  1.763000e+06  6.564000e+00  73930.0  368600.0
# 918  1.759000e+06  6.431000e+00  73890.0  366000.0
# 919  1.756000e+06  6.301000e+00  73860.0  363400.0
# 920  1.752000e+06  6.174000e+00  73820.0  360800.0
#
# [921 rows x 9 columns]

# %%
#Grab the density column for each latitude and put it into dataframe


data_summer = pd.DataFrame()
data_summer['height, km']= summer0['height, km']
lst = ['-90', '-80', '-60', '-40', '-20', '0', '20', '40', '60', '80', '90']
tmp = [summer90s, summer80s, summer60s, summer40s, summer20s, summer0, summer20n, summer40n, summer60n, summer80n, summer90n]
i = 0
for frame in lst:
    data_summer['{}'.format(frame)] = tmp[i]['Mass_density, g/cm-3']
    i = i+1

data_summer
# Out:
#      height, km           -90           -80           -60           -40  \
# 0          40.0  1.791000e-06  1.876000e-06  2.665000e-06  3.716000e-06
# 1          40.5  1.663000e-06  1.742000e-06  2.473000e-06  3.450000e-06
# 2          41.0  1.545000e-06  1.619000e-06  2.295000e-06  3.204000e-06
# 3          41.5  1.437000e-06  1.506000e-06  2.132000e-06  2.978000e-06
# 4          42.0  1.337000e-06  1.402000e-06  1.982000e-06  2.769000e-06
# ..          ...           ...           ...           ...           ...
# 916       498.0  6.506000e-16  5.346000e-16  5.070000e-16  6.123000e-16
# 917       498.5  6.454000e-16  5.302000e-16  5.027000e-16  6.072000e-16
# 918       499.0  6.403000e-16  5.258000e-16  4.984000e-16  6.021000e-16
# 919       499.5  6.353000e-16  5.215000e-16  4.942000e-16  5.971000e-16
# 920       500.0  6.303000e-16  5.172000e-16  4.899000e-16  5.922000e-16
#
#               -20             0            20            40            60  \
# 0    4.140000e-06  4.158000e-06  4.172000e-06  4.325000e-06  4.594000e-06
# 1    3.853000e-06  3.874000e-06  3.888000e-06  4.038000e-06  4.295000e-06
# 2    3.588000e-06  3.611000e-06  3.626000e-06  3.773000e-06  4.019000e-06
# 3    3.343000e-06  3.368000e-06  3.383000e-06  3.526000e-06  3.762000e-06
# 4    3.116000e-06  3.142000e-06  3.158000e-06  3.298000e-06  3.523000e-06
# ..            ...           ...           ...           ...           ...
# 916  6.398000e-16  6.338000e-16  5.779000e-16  5.459000e-16  7.161000e-16
# 917  6.346000e-16  6.286000e-16  5.731000e-16  5.414000e-16  7.107000e-16
# 918  6.295000e-16  6.234000e-16  5.683000e-16  5.370000e-16  7.053000e-16
# 919  6.243000e-16  6.183000e-16  5.636000e-16  5.326000e-16  6.999000e-16
# 920  6.193000e-16  6.133000e-16  5.589000e-16  5.282000e-16  6.946000e-16
#
#                80            90
# 0    4.738000e-06  4.724000e-06
# 1    4.429000e-06  4.414000e-06
# 2    4.141000e-06  4.127000e-06
# 3    3.875000e-06  3.860000e-06
# 4    3.628000e-06  3.613000e-06
# ..            ...           ...
# 916  1.097000e-15  1.305000e-15
# 917  1.089000e-15  1.296000e-15
# 918  1.081000e-15  1.287000e-15
# 919  1.074000e-15  1.278000e-15
# 920  1.066000e-15  1.270000e-15
#
# [921 rows x 12 columns]

# %%
#Take the log of all the entires, remove the height column

array = data_summer.to_numpy()
test = np.delete(array, 0, axis=1)
test2 = np.log10(test)
test2
# Out:
# array([[ -5.74690441,  -5.72676717,  -5.57430279, ...,  -5.33780901,
#          -5.32440494,  -5.32569011],
#        [ -5.77910775,  -5.75895185,  -5.60677588, ...,  -5.36703683,
#          -5.35369432,  -5.35516767],
#        [ -5.81107152,  -5.79075315,  -5.63921731, ...,  -5.39588199,
#          -5.38289477,  -5.38436553],
#        ...,
#        [-15.1936165 , -15.27917942, -15.30242197, ..., -15.15162612,
#         -14.96617431, -14.89042145],
#        [-15.19702114, -15.28274569, -15.30609726, ..., -15.15496401,
#         -14.96899572, -14.89346915],
#        [-15.20045269, -15.28634148, -15.30989256, ..., -15.15826522,
#         -14.9722428 , -14.89619628]])

# %%
#Polyfit, 2 for each latitude (one of degree a and one of degree b)

a = 6
b = 14

y = np.linspace(40,500, num=921)
x = test2[:,1]
p1 = np.polyfit(x, y, a)
p11 = np.polyfit(x, y, b)

y2 = np.linspace(40,500, num=921)
x2 = test2[:,3]
p2= np.polyfit(x2, y2, a)
p22= np.polyfit(x2, y2, b)

y3 = np.linspace(40,500, num=921)
x3 = test2[:,5]
p3 = np.polyfit(x3, y3, a)
p33 = np.polyfit(x3, y3, b)

y4 = np.linspace(40,500, num=921)
x4 = test2[:,7]
p4 = np.polyfit(x4, y4, a)
p44 = np.polyfit(x4, y4, b)

y5 = np.linspace(40,500, num=921)
x5 = test2[:,9]
p5 = np.polyfit(x5, y5, a)
p55 = np.polyfit(x5, y5, b)
# Out:
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#make figure, change font size and figure size

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(ncols = 2, nrows=3)

plt.rcParams.update({'font.size': 22})
fig.set_figheight(18)
fig.set_figwidth(22)


#Three lines on each ax, one for data, and two for the polyfit

data80s = ax1.plot(test2[:,1], y, color = 'red')
regression80s = ax1.plot(x, np.polyval(p1, x), linestyle='dashed', color = 'blue')
regression80s1 = ax1.plot(x, np.polyval(p11, x), linestyle='dashed', color = 'green')

data40s = ax2.plot(test2[:,3], y2, color = 'red')
regression40s = ax2.plot(x2, np.polyval(p2, x2), linestyle='dashed', color = 'blue')
regression40s2 = ax2.plot(x2, np.polyval(p22, x2), linestyle='dashed', color = 'green')

data0 = ax3.plot(test2[:,5], y3, color = 'red')
regression0 = ax3.plot(x3, np.polyval(p3, x3), linestyle='dashed', color = 'blue')
regression03 = ax3.plot(x3, np.polyval(p33, x3), linestyle='dashed', color = 'green')

data40n = ax4.plot(test2[:,7], y4, color = 'red')
regression40n = ax4.plot(x4, np.polyval(p4, x4), linestyle='dashed', color = 'blue')
regression40n4 = ax4.plot(x4, np.polyval(p44, x4), linestyle='dashed', color = 'green')

data80n = ax5.plot(test2[:,9], y5, color = 'red')
regression80n = ax5.plot(x5, np.polyval(p5, x5), linestyle='dashed', color = 'blue')
regression80n5 = ax5.plot(x5, np.polyval(p55, x5), linestyle='dashed', color = 'green')



#Formatting axis

ax1.set_ylim(40, 150)
ax1.set_xlim(-12, -5)
ax1.set_ylabel('height / km')
ax1.set_xlabel('density')
ax1.set_title('North Hemisphere Summer 80 S')
ax1.set_yticks([40,60,80,100, 120, 140])
ax1.grid(True)


ax2.set_ylim(40, 150)
ax2.set_xlim(-12, -5)
ax2.set_ylabel('height / km')
ax2.set_xlabel('density')
ax2.set_title('North Hemisphere Summer 40 S')
ax2.set_yticks([40,60,80,100, 120, 140])
ax2.grid(True)

ax3.set_ylim(40, 150)
ax3.set_xlim(-12, -5)
ax3.set_ylabel('height / km')
ax3.set_xlabel('density')
ax3.set_title('North Hemisphere Summer 0')
ax3.set_yticks([40,60,80,100, 120, 140])
ax3.grid(True)

ax4.set_ylim(40, 150)
ax4.set_xlim(-12, -5)
ax4.set_ylabel('height / km')
ax4.set_xlabel('density')
ax4.set_title('North Hemisphere Summer 40 N')
ax4.set_yticks([40,60,80,100, 120, 140])
ax4.grid(True)

ax5.set_ylim(40, 150)
ax5.set_xlim(-12, -5)
ax5.set_ylabel('height / km')
ax5.set_xlabel('density')
ax5.set_title('North Hemisphere Summer 80 N')
ax5.set_yticks([40,60,80,100, 120, 140])
ax5.grid(True)


ax6.set_visible(False)


#Extra stuff

plt.tight_layout()

fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree 6', 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig('summer_1d_regression_subplots.pdf', bbox_inches='tight')
# Out:
# <ipython-input-185-984ceea4a1b9>:85: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree 6', 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

# %%
#Graph only for one latitude, its also above but I wanted to see it clearly


fig, ax1 = plt.subplots()

plt.rcParams.update({'font.size': 22})
fig.set_figheight(18)
fig.set_figwidth(22)

data80s = ax1.plot(test2[:,1], y, color = 'red')
regression80s = ax1.plot(x, np.polyval(p1, x), linestyle='dashed', color = 'blue')
regression80s1 = ax1.plot(x, np.polyval(p11, x), linestyle='dashed', color = 'green')


ax1.set_ylim(40, 150)
ax1.set_xlim(-12, -5)
ax1.set_ylabel('height / km')
ax1.set_xlabel('density - log10')
ax1.set_title('North Hemisphere Summer 80 S')
ax1.grid(True)

fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree {}'.format(a), 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig('summer_1d_regression_80S.pdf', bbox_inches='tight')
# Out:
# <ipython-input-186-9f2b617d6d3f>:22: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree {}'.format(a), 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

# %%
lst = [p11,p22, p33, p44, p55]
names = [ '80 S', '40 S', '0', '40 N', '80 N']
i=0
for thing in lst:
    print(names[i])
    print(thing)
    print()
    i += 1
# Out:
# 80 S
# [-1.75095089e-08 -2.20177757e-06 -1.21492856e-04 -3.78663544e-03
#  -6.94391471e-02 -6.08585338e-01  3.51938385e+00  1.90750393e+02
#   2.99160531e+03  2.84739030e+04  1.82027692e+05  7.90206864e+05
#   2.24617774e+06  3.78382719e+06  2.86970401e+06]
#
# 40 S
# [-2.26073852e-09 -3.38891680e-07 -2.15893868e-05 -7.61200149e-04
#  -1.56677035e-02 -1.59859697e-01  5.64533436e-01  4.65742430e+01
#   7.98055508e+02  8.06421104e+03  5.40753788e+04  2.44361713e+05
#   7.18917571e+05  1.24759984e+06  9.70824195e+05]
#
# 0
# [ 1.09395569e-08  1.22638023e-06  5.98692559e-05  1.62907536e-03
#   2.52367786e-02  1.55463307e-01 -2.14203014e+00 -6.59265910e+01
#  -8.51951800e+02 -6.94444307e+03 -3.84114808e+04 -1.44654123e+05
#  -3.56403381e+05 -5.18744269e+05 -3.38066842e+05]
#
# 40 N
# [-1.50030959e-08 -1.95026233e-06 -1.10837901e-04 -3.54552192e-03
#  -6.64771326e-02 -5.91541886e-01  3.61191089e+00  1.94868145e+02
#   3.08974407e+03  2.97049743e+04  1.91448731e+05  8.36075280e+05
#   2.38531577e+06  4.02349999e+06  3.04806339e+06]
#
# 80 N
# [ 3.46206746e-08  3.94830513e-06  1.96478275e-04  5.46769438e-03
#   8.73416588e-02  5.84561354e-01 -6.64131521e+00 -2.24090413e+02
#  -2.98716257e+03 -2.48947081e+04 -1.40307754e+05 -5.37434121e+05
#  -1.34565416e+06 -1.99049833e+06 -1.31997281e+06]
