# %%
#Read data from excel files
#File location might vary


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

file = open('/Users/mjalife/Desktop/data_contour/fall0.csv')
fall0 = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/fall20s.csv')
fall20s = pd.read_csv(file)

file = open('/Users/mjalife/Desktop/data_contour/fall20n.csv')
fall20n = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/fall40s.csv')
fall40s = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/fall40n.csv')
fall40n = pd.read_csv(file)

file = open('/Users/mjalife/Desktop/data_contour/fall60s.csv')
fall60s = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/fall60n.csv')
fall60n = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/fall80s.csv')
fall80s = pd.read_csv(file)

file = open('/Users/mjalife/Desktop/data_contour/fall80n.csv')
fall80n = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/fall90s.csv')
fall90s = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/fall90n.csv')
fall90n = pd.read_csv(file)

fall0
# Out:
#      height, km     O, cm-3      N2, cm-3      O2, cm-3  Mass_density, g/cm-3  \
# 0          40.0         0.0  6.611000e+16  1.774000e+16          4.068000e-06
# 1          40.5         0.0  6.168000e+16  1.655000e+16          3.795000e-06
# 2          41.0         0.0  5.758000e+16  1.545000e+16          3.543000e-06
# 3          41.5         0.0  5.378000e+16  1.443000e+16          3.309000e-06
# 4          42.0         0.0  5.026000e+16  1.348000e+16          3.092000e-06
# ..          ...         ...           ...           ...                   ...
# 916       498.0  40210000.0  6.899000e+05  1.181000e+04          1.138000e-15
# 917       498.5  39900000.0  6.807000e+05  1.163000e+04          1.130000e-15
# 918       499.0  39600000.0  6.715000e+05  1.145000e+04          1.121000e-15
# 919       499.5  39290000.0  6.625000e+05  1.128000e+04          1.112000e-15
# 920       500.0  38990000.0  6.536000e+05  1.111000e+04          1.104000e-15
#
#         He, cm-3       Ar, cm-3  H, cm-3   N, cm-3
# 0    4.437000e+11  7.908000e+14      0.0       0.0
# 1    4.139000e+11  7.378000e+14      0.0       0.0
# 2    3.864000e+11  6.887000e+14      0.0       0.0
# 3    3.609000e+11  6.433000e+14      0.0       0.0
# 4    3.373000e+11  6.011000e+14      0.0       0.0
# ..            ...           ...      ...       ...
# 916  3.422000e+06  1.392000e+01  64670.0  634600.0
# 917  3.415000e+06  1.365000e+01  64630.0  630400.0
# 918  3.409000e+06  1.339000e+01  64600.0  626100.0
# 919  3.402000e+06  1.314000e+01  64570.0  621900.0
# 920  3.396000e+06  1.289000e+01  64540.0  617700.0
#
# [921 rows x 9 columns]

# %%
#Grab the density column for each latitude and put it into dataframe


data_fall = pd.DataFrame()
data_fall['height, km']= fall0['height, km']
lst = ['-90', '-80', '-60', '-40', '-20', '0', '20', '40', '60', '80', '90']
tmp = [fall90s, fall80s, fall60s, fall40s, fall20s, fall0, fall20n, fall40n, fall60n, fall80n, fall90n]
i = 0
for frame in lst:
    data_fall['{}'.format(frame)] = tmp[i]['Mass_density, g/cm-3']
    i = i+1

data_fall
# Out:
#      height, km           -90           -80           -60           -40  \
# 0          40.0  2.892000e-06  2.882000e-06  3.350000e-06  3.969000e-06
# 1          40.5  2.709000e-06  2.700000e-06  3.130000e-06  3.701000e-06
# 2          41.0  2.540000e-06  2.531000e-06  2.926000e-06  3.453000e-06
# 3          41.5  2.384000e-06  2.374000e-06  2.737000e-06  3.223000e-06
# 4          42.0  2.238000e-06  2.228000e-06  2.562000e-06  3.010000e-06
# ..          ...           ...           ...           ...           ...
# 916       498.0  1.433000e-15  1.249000e-15  1.038000e-15  1.010000e-15
# 917       498.5  1.423000e-15  1.240000e-15  1.030000e-15  1.002000e-15
# 918       499.0  1.413000e-15  1.232000e-15  1.022000e-15  9.945000e-16
# 919       499.5  1.403000e-15  1.223000e-15  1.015000e-15  9.867000e-16
# 920       500.0  1.394000e-15  1.214000e-15  1.007000e-15  9.790000e-16
#
#               -20             0            20            40            60  \
# 0    4.127000e-06  4.068000e-06  4.127000e-06  4.044000e-06  3.684000e-06
# 1    3.849000e-06  3.795000e-06  3.848000e-06  3.761000e-06  3.412000e-06
# 2    3.591000e-06  3.543000e-06  3.589000e-06  3.500000e-06  3.162000e-06
# 3    3.353000e-06  3.309000e-06  3.350000e-06  3.259000e-06  2.933000e-06
# 4    3.132000e-06  3.092000e-06  3.128000e-06  3.036000e-06  2.722000e-06
# ..            ...           ...           ...           ...           ...
# 916  1.093000e-15  1.138000e-15  1.087000e-15  1.039000e-15  1.079000e-15
# 917  1.084000e-15  1.130000e-15  1.079000e-15  1.031000e-15  1.071000e-15
# 918  1.076000e-15  1.121000e-15  1.071000e-15  1.023000e-15  1.063000e-15
# 919  1.068000e-15  1.112000e-15  1.062000e-15  1.015000e-15  1.055000e-15
# 920  1.059000e-15  1.104000e-15  1.054000e-15  1.007000e-15  1.048000e-15
#
#                80            90
# 0    3.417000e-06  3.438000e-06
# 1    3.157000e-06  3.178000e-06
# 2    2.920000e-06  2.940000e-06
# 3    2.702000e-06  2.721000e-06
# 4    2.502000e-06  2.521000e-06
# ..            ...           ...
# 916  1.255000e-15  1.418000e-15
# 917  1.246000e-15  1.409000e-15
# 918  1.237000e-15  1.399000e-15
# 919  1.229000e-15  1.389000e-15
# 920  1.220000e-15  1.380000e-15
#
# [921 rows x 12 columns]

# %%
#Take the log of all the entires, remove the height column

array = data_fall.to_numpy()
test = np.delete(array, 0, axis=1)
test2 = np.log10(test)
test2
# Out:
# array([[ -5.53880171,  -5.54030602,  -5.47495519, ...,  -5.43368038,
#          -5.46635502,  -5.46369413],
#        [ -5.56719099,  -5.56863624,  -5.50445566, ...,  -5.46699098,
#          -5.50072542,  -5.49784611],
#        [ -5.59516628,  -5.59670785,  -5.53372568, ...,  -5.50003813,
#          -5.53461715,  -5.53165267],
#        ...,
#        [-14.84985784, -14.90938929, -14.9905491 , ..., -14.97346674,
#         -14.9076303 , -14.85418229],
#        [-14.85294233, -14.91257354, -14.99353396, ..., -14.97674754,
#         -14.91044812, -14.85729775],
#        [-14.85573723, -14.91578131, -14.99697053, ..., -14.97963872,
#         -14.91364017, -14.86012091]])

# %%
#Polyfit, 2 for each latitude (one of degree a and one of degree b)

a = 6
b = 14

y = np.linspace(40,500, num=921)
x = test2[:,1]
p1 = np.polyfit(x, y, a)
p11 = np.polyfit(x, y, b)

y2 = np.linspace(40,500, num=921)
x2 = test2[:,3]
p2= np.polyfit(x2, y2, a)
p22= np.polyfit(x2, y2, b)

y3 = np.linspace(40,500, num=921)
x3 = test2[:,5]
p3 = np.polyfit(x3, y3, a)
p33 = np.polyfit(x3, y3, b)

y4 = np.linspace(40,500, num=921)
x4 = test2[:,7]
p4 = np.polyfit(x4, y4, a)
p44 = np.polyfit(x4, y4, b)

y5 = np.linspace(40,500, num=921)
x5 = test2[:,9]
p5 = np.polyfit(x5, y5, a)
p55 = np.polyfit(x5, y5, b)
# Out:
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#make figure, change font size and figure size

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(ncols = 2, nrows=3)

plt.rcParams.update({'font.size': 22})
fig.set_figheight(18)
fig.set_figwidth(22)


#Three lines on each ax, one for data, and two for the polyfit

data80s = ax1.plot(test2[:,1], y, color = 'red')
regression80s = ax1.plot(x, np.polyval(p1, x), linestyle='dashed', color = 'blue')
regression80s1 = ax1.plot(x, np.polyval(p11, x), linestyle='dashed', color = 'green')

data40s = ax2.plot(test2[:,3], y2, color = 'red')
regression40s = ax2.plot(x2, np.polyval(p2, x2), linestyle='dashed', color = 'blue')
regression40s2 = ax2.plot(x2, np.polyval(p22, x2), linestyle='dashed', color = 'green')

data0 = ax3.plot(test2[:,5], y3, color = 'red')
regression0 = ax3.plot(x3, np.polyval(p3, x3), linestyle='dashed', color = 'blue')
regression03 = ax3.plot(x3, np.polyval(p33, x3), linestyle='dashed', color = 'green')

data40n = ax4.plot(test2[:,7], y4, color = 'red')
regression40n = ax4.plot(x4, np.polyval(p4, x4), linestyle='dashed', color = 'blue')
regression40n4 = ax4.plot(x4, np.polyval(p44, x4), linestyle='dashed', color = 'green')

data80n = ax5.plot(test2[:,9], y5, color = 'red')
regression80n = ax5.plot(x5, np.polyval(p5, x5), linestyle='dashed', color = 'blue')
regression80n5 = ax5.plot(x5, np.polyval(p55, x5), linestyle='dashed', color = 'green')



#Formatting axis

ax1.set_ylim(40, 150)
ax1.set_xlim(-12, -5)
ax1.set_ylabel('height / km')
ax1.set_xlabel('density')
ax1.set_title('North Hemisphere fall 80 S')
ax1.set_yticks([40,60,80,100, 120, 140])
ax1.grid(True)


ax2.set_ylim(40, 150)
ax2.set_xlim(-12, -5)
ax2.set_ylabel('height / km')
ax2.set_xlabel('density')
ax2.set_title('North Hemisphere fall 40 S')
ax2.set_yticks([40,60,80,100, 120, 140])
ax2.grid(True)

ax3.set_ylim(40, 150)
ax3.set_xlim(-12, -5)
ax3.set_ylabel('height / km')
ax3.set_xlabel('density')
ax3.set_title('North Hemisphere fall 0')
ax3.set_yticks([40,60,80,100, 120, 140])
ax3.grid(True)

ax4.set_ylim(40, 150)
ax4.set_xlim(-12, -5)
ax4.set_ylabel('height / km')
ax4.set_xlabel('density')
ax4.set_title('North Hemisphere fall 40 N')
ax4.set_yticks([40,60,80,100, 120, 140])
ax4.grid(True)

ax5.set_ylim(40, 150)
ax5.set_xlim(-12, -5)
ax5.set_ylabel('height / km')
ax5.set_xlabel('density')
ax5.set_title('North Hemisphere fall 80 N')
ax5.set_yticks([40,60,80,100, 120, 140])
ax5.grid(True)


ax6.set_visible(False)


#Extra stuff

plt.tight_layout()

fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree 6', 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig('fall_1d_regression_subplots.pdf', bbox_inches='tight')
# Out:
# <ipython-input-7-86c6acc7407c>:85: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree 6', 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

# %%
#Graph only for one latitude, its also above but I wanted to see it clearly


fig, ax1 = plt.subplots()

plt.rcParams.update({'font.size': 22})
fig.set_figheight(18)
fig.set_figwidth(22)

data80s = ax1.plot(test2[:,1], y, color = 'red')
regression80s = ax1.plot(x, np.polyval(p1, x), linestyle='dashed', color = 'blue')
regression80s1 = ax1.plot(x, np.polyval(p11, x), linestyle='dashed', color = 'green')


ax1.set_ylim(40, 150)
ax1.set_xlim(-12, -5)
ax1.set_ylabel('height / km')
ax1.set_xlabel('density - log10')
ax1.set_title('North Hemisphere fall 80 S')
ax1.grid(True)

fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree {}'.format(a), 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig('fall_1d_regression_80S.pdf', bbox_inches='tight')
# Out:
# <ipython-input-6-3aac59628541>:22: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree {}'.format(a), 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

# %%
lst = [p11,p22, p33, p44, p55]
names = [ '80 S', '40 S', '0', '40 N', '80 N']
i=0
for thing in lst:
    print(names[i])
    print(thing)
    print()
    i += 1
# Out:
# 80 S
# [ 2.16290411e-08  2.50792694e-06  1.27412814e-04  3.64333634e-03
#   6.06384266e-02  4.53424060e-01 -3.78870906e+00 -1.52001617e+02
#  -2.15132115e+03 -1.88503908e+04 -1.11687146e+05 -4.50838323e+05
#  -1.19376782e+06 -1.87500040e+06 -1.32619859e+06]
#
# 40 S
# [ 6.01265867e-10 -1.86193366e-08 -5.90114767e-06 -3.30044189e-04
#  -8.85847930e-03 -1.15943428e-01 -1.50809453e-02  2.75436216e+01
#   5.38296074e+02  5.81000274e+03  4.06633699e+04  1.89417412e+05
#   5.69893459e+05  1.00579827e+06  7.92742498e+05]
#
# 0
# [ 2.07574448e-08  2.37405122e-06  1.18715103e-04  3.33010803e-03
#   5.39675323e-02  3.78081403e-01 -3.79014105e+00 -1.36771118e+02
#  -1.87114260e+03 -1.59683158e+04 -9.23239125e+04 -3.63867346e+05
#  -9.40782791e+05 -1.44266521e+06 -9.95992902e+05]
#
# 40 N
# [ 5.44647242e-10 -4.60387413e-09 -4.02902795e-06 -2.38464986e-04
#  -6.53217383e-03 -8.65515036e-02 -2.17514745e-02  2.04206272e+01
#   4.00686370e+02  4.32769425e+03  3.02703369e+04  1.40812854e+05
#   4.22882330e+05  7.44757167e+05  5.85668571e+05]
#
# 80 N
# [ 2.02114939e-08  2.41202607e-06  1.26496266e-04  3.75017328e-03
#   6.52848894e-02  5.31373032e-01 -3.60480058e+00 -1.69578204e+02
#  -2.54367679e+03 -2.34199911e+04 -1.45598812e+05 -6.16855562e+05
#  -1.71574055e+06 -2.83364886e+06 -2.10975090e+06]
