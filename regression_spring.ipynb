# %%
#Read data from excel files
#File location might vary


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

file = open('/Users/mjalife/Desktop/data_contour/spring0.csv')
spring0 = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/spring20s.csv')
spring20s = pd.read_csv(file)

file = open('/Users/mjalife/Desktop/data_contour/spring20n.csv')
spring20n = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/spring40s.csv')
spring40s = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/spring40n.csv')
spring40n = pd.read_csv(file)

file = open('/Users/mjalife/Desktop/data_contour/spring60s.csv')
spring60s = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/spring60n.csv')
spring60n = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/spring80s.csv')
spring80s = pd.read_csv(file)

file = open('/Users/mjalife/Desktop/data_contour/spring80n.csv')
spring80n = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/spring90s.csv')
spring90s = pd.read_csv(file)

file= open('/Users/mjalife/Desktop/data_contour/spring90n.csv')
spring90n = pd.read_csv(file)

spring0
# Out:
#      height, km     O, cm-3      N2, cm-3      O2, cm-3  Mass_density, g/cm-3  \
# 0          40.0         0.0  6.576000e+16  1.764000e+16          4.046000e-06
# 1          40.5         0.0  6.141000e+16  1.648000e+16          3.778000e-06
# 2          41.0         0.0  5.738000e+16  1.539000e+16          3.530000e-06
# 3          41.5         0.0  5.364000e+16  1.439000e+16          3.300000e-06
# 4          42.0         0.0  5.017000e+16  1.346000e+16          3.087000e-06
# ..          ...         ...           ...           ...                   ...
# 916       498.0  54820000.0  1.113000e+06  2.199000e+04          1.562000e-15
# 917       498.5  54420000.0  1.099000e+06  2.168000e+04          1.550000e-15
# 918       499.0  54030000.0  1.085000e+06  2.136000e+04          1.539000e-15
# 919       499.5  53640000.0  1.071000e+06  2.106000e+04          1.528000e-15
# 920       500.0  53250000.0  1.058000e+06  2.075000e+04          1.517000e-15
#
#         He, cm-3       Ar, cm-3  H, cm-3    N, cm-3
# 0    4.413000e+11  7.866000e+14      0.0        0.0
# 1    4.121000e+11  7.346000e+14      0.0        0.0
# 2    3.851000e+11  6.864000e+14      0.0        0.0
# 3    3.600000e+11  6.417000e+14      0.0        0.0
# 4    3.367000e+11  6.001000e+14      0.0        0.0
# ..            ...           ...      ...        ...
# 916  3.903000e+06  2.962000e+01  48600.0  1157000.0
# 917  3.896000e+06  2.909000e+01  48580.0  1150000.0
# 918  3.889000e+06  2.856000e+01  48560.0  1143000.0
# 919  3.882000e+06  2.805000e+01  48540.0  1135000.0
# 920  3.875000e+06  2.754000e+01  48510.0  1128000.0
#
# [921 rows x 9 columns]

# %%
#Grab the density column for each latitude and put it into dataframe


data_spring = pd.DataFrame()
data_spring['height, km']= spring0['height, km']
lst = ['-90', '-80', '-60', '-40', '-20', '0', '20', '40', '60', '80', '90']
tmp = [spring90s, spring80s, spring60s, spring40s, spring20s, spring0, spring20n, spring40n, spring60n, spring80n, spring90n]
i = 0
for frame in lst:
    data_spring['{}'.format(frame)] = tmp[i]['Mass_density, g/cm-3']
    i = i+1

data_spring
# Out:
#      height, km           -90           -80           -60           -40  \
# 0          40.0  3.140000e-06  3.190000e-06  3.614000e-06  3.985000e-06
# 1          40.5  2.912000e-06  2.958000e-06  3.355000e-06  3.706000e-06
# 2          41.0  2.701000e-06  2.746000e-06  3.116000e-06  3.449000e-06
# 3          41.5  2.508000e-06  2.550000e-06  2.896000e-06  3.212000e-06
# 4          42.0  2.330000e-06  2.370000e-06  2.693000e-06  2.993000e-06
# ..          ...           ...           ...           ...           ...
# 916       498.0  1.745000e-15  1.532000e-15  1.348000e-15  1.386000e-15
# 917       498.5  1.733000e-15  1.522000e-15  1.338000e-15  1.376000e-15
# 918       499.0  1.721000e-15  1.511000e-15  1.328000e-15  1.365000e-15
# 919       499.5  1.709000e-15  1.500000e-15  1.318000e-15  1.355000e-15
# 920       500.0  1.698000e-15  1.490000e-15  1.309000e-15  1.345000e-15
#
#               -20             0            20            40            60  \
# 0    4.055000e-06  4.046000e-06  3.995000e-06  3.805000e-06  3.560000e-06
# 1    3.782000e-06  3.778000e-06  3.725000e-06  3.540000e-06  3.308000e-06
# 2    3.530000e-06  3.530000e-06  3.476000e-06  3.297000e-06  3.076000e-06
# 3    3.297000e-06  3.300000e-06  3.246000e-06  3.073000e-06  2.863000e-06
# 4    3.080000e-06  3.087000e-06  3.033000e-06  2.866000e-06  2.667000e-06
# ..            ...           ...           ...           ...           ...
# 916  1.503000e-15  1.562000e-15  1.489000e-15  1.389000e-15  1.438000e-15
# 917  1.492000e-15  1.550000e-15  1.478000e-15  1.379000e-15  1.428000e-15
# 918  1.481000e-15  1.539000e-15  1.467000e-15  1.369000e-15  1.418000e-15
# 919  1.470000e-15  1.528000e-15  1.456000e-15  1.359000e-15  1.408000e-15
# 920  1.459000e-15  1.517000e-15  1.446000e-15  1.349000e-15  1.399000e-15
#
#                80            90
# 0    3.550000e-06  3.672000e-06
# 1    3.297000e-06  3.410000e-06
# 2    3.064000e-06  3.168000e-06
# 3    2.849000e-06  2.945000e-06
# 4    2.651000e-06  2.739000e-06
# ..            ...           ...
# 916  1.727000e-15  1.975000e-15
# 917  1.715000e-15  1.962000e-15
# 918  1.704000e-15  1.949000e-15
# 919  1.693000e-15  1.937000e-15
# 920  1.682000e-15  1.924000e-15
#
# [921 rows x 12 columns]

# %%
#Take the log of all the entires, remove the height column

array = data_spring.to_numpy()
test = np.delete(array, 0, axis=1)
test2 = np.log10(test)
test2
# Out:
# array([[ -5.50307035,  -5.49620932,  -5.44201185, ...,  -5.44855   ,
#          -5.44977165,  -5.43509733],
#        [ -5.53580863,  -5.52900183,  -5.47430748, ...,  -5.4804345 ,
#          -5.48188105,  -5.46724562],
#        [ -5.56847542,  -5.56129947,  -5.50640255, ...,  -5.51201367,
#          -5.51371124,  -5.49921483],
#        ...,
#        [-14.76421913, -14.82073554, -14.87680192, ..., -14.84832377,
#         -14.76853041, -14.71018816],
#        [-14.76725794, -14.82390874, -14.88008459, ..., -14.85139735,
#         -14.77134304, -14.71287038],
#        [-14.77006231, -14.82681373, -14.88306035, ..., -14.85418229,
#         -14.77417401, -14.71579493]])

# %%
#Polyfit, 2 for each latitude (one of degree a and one of degree b)

a = 6
b = 14

y = np.linspace(40,500, num=921)
x = test2[:,1]
p1 = np.polyfit(x, y, a)
p11 = np.polyfit(x, y, b)

y2 = np.linspace(40,500, num=921)
x2 = test2[:,3]
p2= np.polyfit(x2, y2, a)
p22= np.polyfit(x2, y2, b)

y3 = np.linspace(40,500, num=921)
x3 = test2[:,5]
p3 = np.polyfit(x3, y3, a)
p33 = np.polyfit(x3, y3, b)

y4 = np.linspace(40,500, num=921)
x4 = test2[:,7]
p4 = np.polyfit(x4, y4, a)
p44 = np.polyfit(x4, y4, b)

y5 = np.linspace(40,500, num=921)
x5 = test2[:,9]
p5 = np.polyfit(x5, y5, a)
p55 = np.polyfit(x5, y5, b)
# Out:
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/mjalife/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#make figure, change font size and figure size

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(ncols = 2, nrows=3)

plt.rcParams.update({'font.size': 22})
fig.set_figheight(18)
fig.set_figwidth(22)


#Three lines on each ax, one for data, and two for the polyfit

data80s = ax1.plot(test2[:,1], y, color = 'red')
regression80s = ax1.plot(x, np.polyval(p1, x), linestyle='dashed', color = 'blue')
regression80s1 = ax1.plot(x, np.polyval(p11, x), linestyle='dashed', color = 'green')

data40s = ax2.plot(test2[:,3], y2, color = 'red')
regression40s = ax2.plot(x2, np.polyval(p2, x2), linestyle='dashed', color = 'blue')
regression40s2 = ax2.plot(x2, np.polyval(p22, x2), linestyle='dashed', color = 'green')

data0 = ax3.plot(test2[:,5], y3, color = 'red')
regression0 = ax3.plot(x3, np.polyval(p3, x3), linestyle='dashed', color = 'blue')
regression03 = ax3.plot(x3, np.polyval(p33, x3), linestyle='dashed', color = 'green')

data40n = ax4.plot(test2[:,7], y4, color = 'red')
regression40n = ax4.plot(x4, np.polyval(p4, x4), linestyle='dashed', color = 'blue')
regression40n4 = ax4.plot(x4, np.polyval(p44, x4), linestyle='dashed', color = 'green')

data80n = ax5.plot(test2[:,9], y5, color = 'red')
regression80n = ax5.plot(x5, np.polyval(p5, x5), linestyle='dashed', color = 'blue')
regression80n5 = ax5.plot(x5, np.polyval(p55, x5), linestyle='dashed', color = 'green')



#Formatting axis

ax1.set_ylim(40, 150)
ax1.set_xlim(-12, -5)
ax1.set_ylabel('height / km')
ax1.set_xlabel('density')
ax1.set_title('North Hemisphere spring 80 S')
ax1.set_yticks([40,60,80,100, 120, 140])
ax1.grid(True)


ax2.set_ylim(40, 150)
ax2.set_xlim(-12, -5)
ax2.set_ylabel('height / km')
ax2.set_xlabel('density')
ax2.set_title('North Hemisphere spring 40 S')
ax2.set_yticks([40,60,80,100, 120, 140])
ax2.grid(True)

ax3.set_ylim(40, 150)
ax3.set_xlim(-12, -5)
ax3.set_ylabel('height / km')
ax3.set_xlabel('density')
ax3.set_title('North Hemisphere spring 0')
ax3.set_yticks([40,60,80,100, 120, 140])
ax3.grid(True)

ax4.set_ylim(40, 150)
ax4.set_xlim(-12, -5)
ax4.set_ylabel('height / km')
ax4.set_xlabel('density')
ax4.set_title('North Hemisphere spring 40 N')
ax4.set_yticks([40,60,80,100, 120, 140])
ax4.grid(True)

ax5.set_ylim(40, 150)
ax5.set_xlim(-12, -5)
ax5.set_ylabel('height / km')
ax5.set_xlabel('density')
ax5.set_title('North Hemisphere spring 80 N')
ax5.set_yticks([40,60,80,100, 120, 140])
ax5.grid(True)


ax6.set_visible(False)


#Extra stuff

plt.tight_layout()

fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree 6', 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig('spring_1d_regression_subplots.pdf', bbox_inches='tight')
# Out:
# <ipython-input-13-ab2acee296f5>:85: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree 6', 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

# %%
#Graph only for one latitude, its also above but I wanted to see it clearly


fig, ax1 = plt.subplots()

plt.rcParams.update({'font.size': 22})
fig.set_figheight(18)
fig.set_figwidth(22)

data80s = ax1.plot(test2[:,1], y, color = 'red')
regression80s = ax1.plot(x, np.polyval(p1, x), linestyle='dashed', color = 'blue')
regression80s1 = ax1.plot(x, np.polyval(p11, x), linestyle='dashed', color = 'green')


ax1.set_ylim(40, 150)
ax1.set_xlim(-12, -5)
ax1.set_ylabel('height / km')
ax1.set_xlabel('density - log10')
ax1.set_title('North Hemisphere spring 80 S')
ax1.grid(True)

fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree {}'.format(a), 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig('spring_1d_regression_80S.pdf', bbox_inches='tight')
# Out:
# <ipython-input-14-17516c8cd706>:22: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend([data80s, regression80s, regression80s1 ], labels = ['data ', 'polyfit degree {}'.format(a), 'polyfit degree {}'.format(b)], loc='center left', bbox_to_anchor=(1, 0.5))

# %%
lst = [p11,p22, p33, p44, p55]
names = [ '80 S', '40 S', '0', '40 N', '80 N']
i=0
for thing in lst:
    print(names[i])
    print(thing)
    print()
    i += 1
# Out:
# 80 S
# [ 2.88337786e-08  3.40906727e-06  1.77050440e-04  5.19539533e-03
#   8.94604427e-02  7.18912344e-01 -4.87136472e+00 -2.25317806e+02
#  -3.33727627e+03 -3.03469537e+04 -1.86333181e+05 -7.79725955e+05
#  -2.14239081e+06 -3.49616302e+06 -2.57296924e+06]
#
# 40 S
# [ 1.01895649e-08  1.13875576e-06  5.54368332e-05  1.50573758e-03
#   2.33754365e-02  1.48988425e-01 -1.78454698e+00 -5.67895024e+01
#  -7.29429879e+02 -5.85637558e+03 -3.16866181e+04 -1.15838001e+05
#  -2.74410914e+05 -3.79131254e+05 -2.30349291e+05]
#
# 0
# [ 3.76782401e-08  4.38673187e-06  2.23878900e-04  6.43551165e-03
#   1.07847353e-01  8.18515039e-01 -6.56305796e+00 -2.70473299e+02
#  -3.86271972e+03 -3.41024830e+04 -2.03586086e+05 -8.28415497e+05
#  -2.21280807e+06 -3.50926061e+06 -2.50883619e+06]
#
# 40 N
# [ 1.00034856e-08  1.09528362e-06  5.19597614e-05  1.36334256e-03
#   2.00631219e-02  1.09395052e-01 -1.76173175e+00 -4.71719233e+01
#  -5.46005894e+02 -3.88247703e+03 -1.77819270e+04 -5.02716287e+04
#  -7.39638874e+04 -1.87665173e+04  5.94224994e+04]
#
# 80 N
# [ 2.94927981e-08  3.49764810e-06  1.82104020e-04  5.35362721e-03
#   9.22888551e-02  7.41664905e-01 -5.03839467e+00 -2.32483999e+02
#  -3.43670951e+03 -3.11696851e+04 -1.90748639e+05 -7.94989157e+05
#  -2.17408900e+06 -3.52910061e+06 -2.58202773e+06]
